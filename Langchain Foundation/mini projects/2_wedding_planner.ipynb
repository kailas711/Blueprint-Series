# %% [markdown]
# ### Wedding Planner

# %%
from langchain_community.utilities import SQLDatabase

PATH = "sqlite:///D://Coding Stuff//GitHub//Blueprint-Series//Langchain Foundation//resources//Chinook.db"
db = SQLDatabase.from_uri(PATH)
db
