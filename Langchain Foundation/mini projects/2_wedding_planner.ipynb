# %% [markdown]
# # Wedding Planner

# %%
from langchain_community.utilities import SQLDatabase

PATH = "sqlite:///resources//Chinook.db"
db = SQLDatabase.from_uri(PATH)
db

# %% [markdown]
# ### Setup Tools

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from typing import Dict, Any
from tavily import TavilyClient
from langchain.tools import tool

tavily_client = TavilyClient("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")

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
from langchain_community.utilities import SQLDatabase
db = SQLDatabase.from_uri("sqlite:///D:/Coding Stuff/GitHub/Blueprint-Series/Langchain Foundation/resources/Chinook.db")

@tool
def query_playlist_db(query: str) -> str:
    """Query the database for playlist information"""
    try:
        return db.run(query)
    except Exception as e:
        return f"Error querying database: {e}"

# %% [markdown]
# ### Create State

# %%
from langchain.agents import AgentState

class WeddingState(AgentState):
    origin: str
    destination: str
    guest_count: str
    genre: str

# %% [markdown]
# ### Create Subagents

# %%
from langchain.agents import create_agent
from langchain_ollama import ChatOllama
model = ChatOllama(model="llama3.2:1b")
# Travel agent
travel_agent = create_agent(
    model,
    tools=tools,
    system_prompt="""
    You are a travel agent. Search for flights to the desired destination wedding location.
    You are not allowed to ask any more follow up questions, you must find the best flight options based on the following criteria:
    - Price (lowest, economy class)
    - Duration (shortest)
    - Date (time of year which you believe is best for a wedding at this location)
    To make things easy, only look for one ticket, one way.
    You may need to make multiple searches to iteratively find the best options.
    You will be given no extra information, only the origin and destination. It is your job to think critically about the best options.
    Once you have found the best options, let the user know your shortlist of options.
    """
)

# %%
# Venue agent
venue_agent = create_agent(
    model,
    tools=[web_search],
    system_prompt="""
    You are a venue specialist. Search for venues in the desired location, and with the desired capacity.
    You are not allowed to ask any more follow up questions, you must find the best venue options based on the following criteria:
    - Price (lowest)
    - Capacity (exact match)
    - Reviews (highest)
    You may need to make multiple searches to iteratively find the best options.
    """
)

# %%
# Playlist agent
playlist_agent = create_agent(
    model,
    tools=[query_playlist_db],
    system_prompt="""
    You are a playlist specialist. Query the sql database and curate the perfect playlist for a wedding given a genre.
    Once you have your playlist, calculate the total duration and cost of the playlist, each song has an associated price.
    If you run into errors when querying the database, try to fix them by making changes to the query.
    Do not come back empty handed, keep trying to query the db until you find a list of songs.
    You may need to make multiple queries to iteratively find the best options.
    """
)

# %% [markdown]
# ### Main Coordinator

# %%
from langchain.tools import ToolRuntime
from langchain.messages import HumanMessage, ToolMessage
from langgraph.types import Command

@tool
async def search_flights(runtime: ToolRuntime) -> str:
    """Travel agent searches for flights to the desired destination wedding location."""
    origin = runtime.state["origin"]
    destination = runtime.state["destination"]
    response = await travel_agent.ainvoke({"messages": [HumanMessage(content=f"Find flights from {origin} to {destination}")]})
    return response['messages'][-1].content

@tool
def search_venues(runtime: ToolRuntime) -> str:
    """Venue agent chooses the best venue for the given location and capacity."""
    destination = runtime.state["destination"]
    capacity = runtime.state["guest_count"]
    query = f"Find wedding venues in {destination} for {capacity} guests"
    response = venue_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def suggest_playlist(runtime: ToolRuntime) -> str:
    """Playlist agent curates the perfect playlist for the given genre."""
    genre = runtime.state["genre"]
    query = f"Find {genre} tracks for wedding playlist"
    response = playlist_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def update_state(origin: str, destination: str, guest_count: str, genre: str, runtime: ToolRuntime) -> str:
    """Update the state when you know all of the values: origin, destination, guest_count, genre"""
    return Command(update={
        "origin": origin, 
        "destination": destination, 
        "guest_count": guest_count, 
        "genre": genre, 
        "messages": [ToolMessage("Successfully updated state", tool_call_id=runtime.tool_call_id)]}
        )

# %%
from langchain.agents import create_agent

coordinator = create_agent(
    model,
    tools=[search_flights, search_venues, suggest_playlist, update_state],
    state_schema=WeddingState,
    system_prompt="""
    You are a wedding coordinator. Delegate tasks to your specialists for flights, venues and playlists.
    First find all the information you need to update the state. Once that is done you can delegate the tasks.
    Once you have received their answers, coordinate the perfect wedding for me.
    """
)

# %%
from langchain.messages import HumanMessage

response = await coordinator.ainvoke(
    {
        "messages": [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre")],
    }
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 3
#       1 from langchain.messages import HumanMessage
# ----> 3 response = await coordinator.ainvoke(
#       4     {
#       5         "messages": [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre")],
#       6     }
#       7 )
#
# File c:\Users\kaila\projects\lib\site-packages\langgraph\pregel\main.py:3158, in Pregel.ainvoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3155 chunks: list[dict[str, Any] | Any] = []
#    3156 interrupts: list[Interrupt] = []
# -> 3158 async for chunk in self.astream(
#    3159     input,
#    3160     config,
#    3161     context=context,
#    3162     stream_mode=["updates", "values"]
#    3163     if stream_mode == "values"
#    3164     else stream_mode,
#    3165     print_mode=print_mode,
#    3166     output_keys=output_keys,
#    3167     interrupt_before=interrupt_before,
#    3168     interrupt_after=interrupt_after,
#    3169     durability=durability,
#    3170     **kwargs,
#    3171 ):
#    3172     if stream_mode == "values":
#    3173         if len(chunk) == 2:
#
# File c:\Users\kaila\projects\lib\site-packages\langgraph\pregel\main.py:2971, in Pregel.astream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2969 for task in await loop.amatch_cached_writes():
#    2970     loop.output_writes(task.id, task.writes, cached=True)
# -> 2971 async for _ in runner.atick(
#    2972     [t for t in loop.tasks.values() if not t.writes],
#    2973     timeout=self.step_timeout,
#    2974     get_waiter=get_waiter,
#    2975     schedule_task=loop.aaccept_push,
#    2976 ):
#    2977     # emit output
#    2978     for o in _output(
#    2979         stream_mode,
#    2980         print_mode,
#    (...)
#    2983         asyncio.QueueEmpty,
#    2984     ):
#    2985         yield o
#
# File c:\Users\kaila\projects\lib\site-packages\langgraph\pregel\_runner.py:304, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     302 t = tasks[0]
#     303 try:
# --> 304     await arun_with_retry(
#     305         t,
#     306         retry_policy,
#     307         stream=self.use_astream,
#     308         configurable={
#     309             CONFIG_KEY_CALL: partial(
#     310                 _acall,
#     311                 weakref.ref(t),
#     312                 stream=self.use_astream,
#     313                 retry_policy=retry_policy,
#     314                 futures=weakref.ref(futures),
#     315                 schedule_task=schedule_task,
#     316                 submit=self.submit,
#     317                 loop=loop,
#     318             ),
#     319         },
#     320     )
#     321     self.commit(t, None)
#     322 except Exception as exc:
#
# File c:\Users\kaila\projects\lib\site-packages\langgraph\pregel\_retry.py:137, in arun_with_retry(task, retry_policy, stream, match_cached_writes, configurable)
#     135         break
#     136     else:
# --> 137         return await task.proc.ainvoke(task.input, config)
#     138 except ParentCommand as exc:
#     139     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\kaila\projects\lib\site-packages\langgraph\_internal\_runnable.py:709, in RunnableSeq.ainvoke(self, input, config, **kwargs)
#     705             input = await asyncio.create_task(
#     706                 step.ainvoke(input, config, **kwargs), context=context
#     707             )
#     708     else:
# --> 709         input = await step.ainvoke(input, config, **kwargs)
#     710 else:
#     711     input = await step.ainvoke(input, config)
#
# File c:\Users\kaila\projects\lib\site-packages\langgraph\_internal\_runnable.py:473, in RunnableCallable.ainvoke(self, input, config, **kwargs)
#     471         await run_manager.on_chain_end(ret)
#     472 else:
# --> 473     ret = await self.afunc(*args, **kwargs)
#     474 if self.recurse and isinstance(ret, Runnable):
#     475     return await ret.ainvoke(input, config)
#
# File c:\Users\kaila\projects\lib\site-packages\langgraph\prebuilt\tool_node.py:832, in ToolNode._afunc(self, input, config, runtime)
#     830 for call, tool_runtime in zip(tool_calls, tool_runtimes, strict=False):
#     831     coros.append(self._arun_one(call, input_type, tool_runtime))  # type: ignore[arg-type]
# --> 832 outputs = await asyncio.gather(*coros)
#     834 return self._combine_tool_outputs(outputs, input_type)
#
# File c:\Users\kaila\projects\lib\site-packages\langgraph\prebuilt\tool_node.py:1163, in ToolNode._arun_one(self, call, input_type, tool_runtime)
#    1159 config = tool_runtime.config
#    1161 if self._awrap_tool_call is None and self._wrap_tool_call is None:
#    1162     # No wrapper - execute directly
# -> 1163     return await self._execute_tool_async(tool_request, input_type, config)
#    1165 # Define async execute callable that can be called multiple times
#    1166 async def execute(req: ToolCallRequest) -> ToolMessage | Command:
#
# File c:\Users\kaila\projects\lib\site-packages\langgraph\prebuilt\tool_node.py:1112, in ToolNode._execute_tool_async(self, request, input_type, config)
#    1109         raise
#    1111     # Error is handled - create error ToolMessage
# -> 1112     content = _handle_tool_error(e, flag=self._handle_tool_errors)
#    1113     return ToolMessage(
#    1114         content=content,
#    1115         name=call["name"],
#    1116         tool_call_id=call["id"],
#    1117         status="error",
#    1118     )
#    1120 # Process successful response
#
# File c:\Users\kaila\projects\lib\site-packages\langgraph\prebuilt\tool_node.py:424, in _handle_tool_error(e, flag)
#     422     content = flag
#     423 elif callable(flag):
# --> 424     content = flag(e)  # type: ignore [assignment, call-arg]
#     425 else:
#     426     msg = (
#     427         f"Got unexpected type of `handle_tool_error`. Expected bool, str "
#     428         f"or callable. Received: {flag}"
#     429     )
#
# File c:\Users\kaila\projects\lib\site-packages\langgraph\prebuilt\tool_node.py:381, in _default_handle_tool_errors(e)
#     379 if isinstance(e, ToolInvocationError):
#     380     return e.message
# --> 381 raise e
#
# File c:\Users\kaila\projects\lib\site-packages\langgraph\prebuilt\tool_node.py:1069, in ToolNode._execute_tool_async(self, request, input_type, config)
#    1067 try:
#    1068     try:
# -> 1069         response = await tool.ainvoke(call_args, config)
#    1070     except ValidationError as exc:
#    1071         # Filter out errors for injected arguments
#    1072         injected = self._injected_args.get(call["name"])
#
# File c:\Users\kaila\projects\lib\site-packages\langchain_core\tools\structured.py:66, in StructuredTool.ainvoke(self, input, config, **kwargs)
#      62 if not self.coroutine:
#      63     # If the tool does not implement async, fall back to default implementation
#      64     return await run_in_executor(config, self.invoke, input, config, **kwargs)
# ---> 66 return await super().ainvoke(input, config, **kwargs)
#
# File c:\Users\kaila\projects\lib\site-packages\langchain_core\tools\base.py:639, in BaseTool.ainvoke(self, input, config, **kwargs)
#     631 @override
#     632 async def ainvoke(
#     633     self,
#    (...)
#     636     **kwargs: Any,
#     637 ) -> Any:
#     638     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 639     return await self.arun(tool_input, **kwargs)
#
# File c:\Users\kaila\projects\lib\site-packages\langchain_core\tools\base.py:1111, in BaseTool.arun(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#    1109 if error_to_raise:
#    1110     await run_manager.on_tool_error(error_to_raise)
# -> 1111     raise error_to_raise
#    1113 output = _format_output(content, artifact, tool_call_id, self.name, status)
#    1114 await run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File c:\Users\kaila\projects\lib\site-packages\langchain_core\tools\base.py:1077, in BaseTool.arun(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#    1074         tool_kwargs[config_param] = config
#    1076     coro = self._arun(*tool_args, **tool_kwargs)
# -> 1077     response = await coro_with_context(coro, context)
#    1078 if self.response_format == "content_and_artifact":
#    1079     msg = (
#    1080         "Since response_format='content_and_artifact' "
#    1081         "a two-tuple of the message content and raw tool output is "
#    1082         f"expected. Instead, generated response is of type: "
#    1083         f"{type(response)}."
#    1084     )
#
# File c:\Users\kaila\projects\lib\site-packages\langchain_core\tools\structured.py:120, in StructuredTool._arun(self, config, run_manager, *args, **kwargs)
#     118     if config_param := _get_runnable_config_param(self.coroutine):
#     119         kwargs[config_param] = config
# --> 120     return await self.coroutine(*args, **kwargs)
#     122 # If self.coroutine is None, then this will delegate to the default
#     123 # implementation which is expected to delegate to _run on a separate thread.
#     124 return await super()._arun(
#     125     *args, config=config, run_manager=run_manager, **kwargs
#     126 )
#
# Cell In[9], line 8, in search_flights(runtime)
#       5 @tool
#       6 async def search_flights(runtime: ToolRuntime) -> str:
#       7     """Travel agent searches for flights to the desired destination wedding location."""
# ----> 8     origin = runtime.state["origin"]
#       9     destination = runtime.state["destination"]
#      10     response = await travel_agent.ainvoke({"messages": [HumanMessage(content=f"Find flights from {origin} to {destination}")]})
#
# KeyError: 'origin'

# %%
from pprint import pprint

pprint(response)
